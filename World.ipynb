# %%
import pandas as pd, numpy as np
# %matplotlib inline
import matplotlib
matplotlib.rc('figure', figsize=(8,8))

# %% [markdown]
# # From [Our world in data](https://ourworldindata.org/coronavirus-data)
#
# - [Full data](https://ourworldindata.org/coronavirus#we-rely-on-data-from-the-european-cdc)
#
# - [Also](https://ourworldindata.org/coronavirus#our-world-in-data-relies-on-data-from-the-european-cdc)
#
# ## Italy

# %%
world = pd.read_csv('full_data.csv')
italy = world.loc[lambda df: df['location'] == 'Italy']
italy = italy.rename(columns={'new_cases':'daily_cases',
                              'new_deaths':'daily_deaths'})
italy.insert(3, 'cases', np.cumsum(italy['daily_cases']))
italy.insert(3, 'deaths', np.cumsum(italy['daily_deaths']))
italy.plot.bar(y=['total_cases', 'daily_cases'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11977b990>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11ec3b790>],
#       dtype=object)

# %%
italy.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11e3a1490>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x119d0dad0>],
#       dtype=object)

# %%
italy[['deaths', 'date']]
# Out:
#       deaths        date
# 5314       0  2019-12-31
# 5315       0  2020-01-01
# 5316       0  2020-01-02
# 5317       0  2020-01-03
# 5318       0  2020-01-04
# ...      ...         ...
# 5417   19470  2020-04-12
# 5418   19901  2020-04-13
# 5419   20465  2020-04-14
# 5420   21069  2020-04-15
# 5421   21647  2020-04-16
#
# [108 rows x 2 columns]

# %% [markdown]
# ## USA

# %%
usa = world.loc[lambda df: df['location'] == 'United States']
usa = usa.rename(columns={'new_cases':'daily_cases',
                          'new_deaths':'daily_deaths'})
usa.insert(3, 'cases', np.cumsum(usa['daily_cases']))
usa.insert(3, 'deaths', np.cumsum(usa['daily_deaths']))
usa.plot.bar(y=['cases', 'daily_cases'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11f512810>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11f94cfd0>],
#       dtype=object)

# %%
usa.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11fc1d590>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11ffd8810>],
#       dtype=object)

# %%
usa[['daily_deaths', 'date']]
# Out:
#        daily_deaths        date
# 10723             0  2019-12-31
# 10724             0  2020-01-01
# 10725             0  2020-01-02
# 10726             0  2020-01-03
# 10727             0  2020-01-04
# ...             ...         ...
# 10826          1831  2020-04-12
# 10827          1500  2020-04-13
# 10828          1541  2020-04-14
# 10829          2408  2020-04-15
# 10830          4928  2020-04-16
#
# [108 rows x 2 columns]

# %%
usa[['deaths', 'date']]
# Out:
#        deaths        date
# 10723       0  2019-12-31
# 10724       0  2020-01-01
# 10725       0  2020-01-02
# 10726       0  2020-01-03
# 10727       0  2020-01-04
# ...       ...         ...
# 10826   20608  2020-04-12
# 10827   22108  2020-04-13
# 10828   23649  2020-04-14
# 10829   26057  2020-04-15
# 10830   30985  2020-04-16
#
# [108 rows x 2 columns]

# %% [markdown]
# ## Canada

# %%
canada = world.loc[lambda df: df['location'] == 'Canada']
canada = canada.rename(columns={'new_cases':'daily_cases',
                          'new_deaths':'daily_deaths'})
canada.insert(3, 'cases', np.cumsum(canada['daily_cases']))
canada.insert(3, 'deaths', np.cumsum(canada['daily_deaths']))
canada.plot.bar(y=['cases', 'daily_cases'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x119e7a650>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x120666c90>],
#       dtype=object)

# %%
canada.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x120c84fd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x120cfeed0>],
#       dtype=object)

# %% [markdown]
# ## South Korea

# %%
korea = world.loc[lambda df: df['location'] == 'South Korea']
korea = korea.rename(columns={'new_cases':'daily_cases',
                          'new_deaths':'daily_deaths'})
korea.insert(3, 'cases', np.cumsum(korea['daily_cases']))
korea.insert(3, 'deaths', np.cumsum(korea['daily_deaths']))
korea.plot.bar(y=['cases', 'daily_cases'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x121099ad0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x12138fbd0>],
#       dtype=object)

# %%
korea.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1217211d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x121a1ac90>],
#       dtype=object)

# %% [markdown]
# ## Japan

# %%
japan = world.loc[lambda df: df['location'] == 'Japan']
japan = japan.rename(columns={'new_cases':'daily_cases',
                          'new_deaths':'daily_deaths'})
japan.insert(3, 'cases', np.cumsum(japan['daily_cases']))
japan.insert(3, 'deaths', np.cumsum(japan['daily_deaths']))
japan.plot.bar(y=['cases', 'daily_cases'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12204b690>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1221bdb50>],
#       dtype=object)

# %%
japan.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1226d6f90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x122749f10>],
#       dtype=object)

# %% [markdown]
# ## Belgium

# %%
belgium = world.loc[lambda df: df['location'] == 'Belgium']
belgium = belgium.rename(columns={'new_cases':'daily_cases',
                          'new_deaths':'daily_deaths'})
belgium.insert(3, 'cases', np.cumsum(belgium['daily_cases']))
belgium.insert(3, 'deaths', np.cumsum(belgium['daily_deaths']))
belgium.plot.bar(y=['cases', 'daily_cases'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1226ff790>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x122ef5e10>],
#       dtype=object)

# %%
belgium.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12300dc50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x12346b750>],
#       dtype=object)

# %%
np.sum(italy['daily_deaths']), np.sum(usa['daily_deaths']), np.sum(canada['daily_deaths'])
# Out:
# (21647, 30985, 1010)
