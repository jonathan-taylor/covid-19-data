# %%
import pandas as pd, numpy as np
# %matplotlib inline
import matplotlib
matplotlib.rc('figure', figsize=(8,8))

# %%
states = pd.read_csv('us-states.csv')
daily = states.groupby(by='date')
states.columns
# Out:
# Index(['date', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %% [markdown]
# ## US deaths & cases

# %%
totals = daily.sum()

# %%
daily_deaths = np.asarray(totals['deaths']).copy()
daily_deaths[1:] = daily_deaths[1:] - daily_deaths[:-1]
totals.insert(3, 'daily_deaths', daily_deaths)
totals.plot.bar(y=['deaths', 'daily_deaths'], subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11bb5edd8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11bbb0c50>],
#       dtype=object)

# %%
daily_cases = np.asarray(totals['cases']).copy()
daily_cases[1:] = daily_cases[1:] - daily_cases[:-1]
totals.insert(3, 'daily_cases', daily_cases)
totals.plot.bar(y=['cases', 'daily_cases'], subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11bf35c50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11bfe8d68>],
#       dtype=object)

# %% [markdown]
# ## Last few days

# %%
totals[-3:]
# Out:
#             fips   cases  deaths  daily_cases  daily_deaths
# date
# 2020-04-06  1762  366238   10959        29464          1304
# 2020-04-07  1762  397754   12956        31516          1997
# 2020-04-08  1762  429319   14827        31565          1871

# %% [markdown]
# ## California deaths & cases

# %%
cali = states.loc[lambda df: df['state'] == 'California']

# %%
daily_ca_deaths = np.asarray(cali['deaths']).copy()
daily_ca_deaths[1:] = daily_ca_deaths[1:] - daily_ca_deaths[:-1]
cali.insert(3, 'daily_deaths', daily_ca_deaths)
cali.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11c148b00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11c18b978>],
#       dtype=object)

# %%
daily_ca_cases = np.asarray(cali['cases']).copy()
daily_ca_cases[1:] = daily_ca_cases[1:] - daily_ca_cases[:-1]
cali.insert(3, 'daily_cases', daily_ca_cases)
cali.plot.bar(y=['cases', 'daily_cases'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11c44dc18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11c61f278>],
#       dtype=object)

# %% [markdown]
# ## New York deaths & cases

# %%
ny = states.loc[lambda df: df['state'] == 'New York']
ny.columns
# Out:
# Index(['date', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
daily_ny_deaths = np.asarray(ny['deaths']).copy()
daily_ny_deaths[1:] = daily_ny_deaths[1:] - daily_ny_deaths[:-1]
ny.insert(3, 'daily_deaths', daily_ny_deaths)
ny.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11c7ca5c0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11cad0128>],
#       dtype=object)

# %%
daily_ny_cases = np.asarray(ny['cases']).copy()
daily_ny_cases[1:] = daily_ny_cases[1:] - daily_ny_cases[:-1]
ny.insert(3, 'daily_cases', daily_ny_cases)
ny.plot.bar(y=['cases', 'daily_cases'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11cc8ce10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11ce37cc0>],
#       dtype=object)

# %% [markdown]
# ## Florida deaths & cases

# %%
fl = states.loc[lambda df: df['state'] == 'Florida']

# %%
daily_fl_deaths = np.asarray(fl['deaths']).copy()
daily_fl_deaths[1:] = daily_fl_deaths[1:] - daily_fl_deaths[:-1]
fl.insert(3, 'daily_deaths', daily_fl_deaths)
fl.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11cfc1400>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d17c160>],
#       dtype=object)

# %%
daily_fl_cases = np.asarray(fl['cases']).copy()
daily_fl_cases[1:] = daily_fl_cases[1:] - daily_fl_cases[:-1]
fl.insert(3, 'daily_cases', daily_fl_cases)
fl.plot.bar(y=['cases', 'daily_cases'], subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11d47c780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d490ba8>],
#       dtype=object)

# %% [markdown]
# ## Texas deaths & cases

# %%
tx = states.loc[lambda df: df['state'] == 'Texas']

# %%
daily_tx_deaths = np.asarray(tx['deaths']).copy()
daily_tx_deaths[1:] = daily_tx_deaths[1:] - daily_tx_deaths[:-1]
tx.insert(3, 'daily_deaths', daily_tx_deaths)
tx.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11d793e80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d7e0828>],
#       dtype=object)

# %%
daily_tx_cases = np.asarray(tx['cases']).copy()
daily_tx_cases[1:] = daily_tx_cases[1:] - daily_tx_cases[:-1]
tx.insert(3, 'daily_cases', daily_tx_cases)
tx.plot.bar(y=['cases', 'daily_cases'], subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11d8742e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11dae6470>],
#       dtype=object)

# %% [markdown]
# ## Louisiana deaths & cases

# %%
la = states.loc[lambda df: df['state'] == 'Louisiana']
daily_la_deaths = np.asarray(la['deaths']).copy()
daily_la_deaths[1:] = daily_la_deaths[1:] - daily_la_deaths[:-1]
la.insert(3, 'daily_deaths', daily_la_deaths)
la.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11de09c50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11deda048>],
#       dtype=object)

# %%
daily_la_cases = np.asarray(la['cases']).copy()
daily_la_cases[1:] = daily_la_cases[1:] - daily_la_cases[:-1]
la.insert(3, 'daily_cases', daily_la_cases)
la.plot.bar(y=['cases', 'daily_cases'], subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11e0527f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11e1a8d68>],
#       dtype=object)

# %% [markdown]
# ## Tennessee deaths & cases

# %%
tn = states.loc[lambda df: df['state'] == 'Tennessee']
daily_tn_deaths = np.asarray(tn['deaths']).copy()
daily_tn_deaths[1:] = daily_tn_deaths[1:] - daily_tn_deaths[:-1]
tn.insert(3, 'daily_deaths', daily_tn_deaths)
tn.plot.bar(y=['deaths', 'daily_deaths'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11e477cc0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11e497198>],
#       dtype=object)

# %%
daily_tn_cases = np.asarray(tn['cases']).copy()
daily_tn_cases[1:] = daily_tn_cases[1:] - daily_tn_cases[:-1]
tn.insert(3, 'daily_cases', daily_tn_cases)
tn.plot.bar(y=['cases', 'daily_cases'], x='date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11e605390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11e796c50>],
#       dtype=object)

# %% [markdown]
# # From [Our world in data](https://ourworldindata.org/coronavirus-data)
#
# ## Italy

# %%
world = pd.read_csv('daily-covid-cases-deaths.csv')
italy = world.loc[lambda df: df['Entity'] == 'Italy']
italy = italy.rename(columns={'Daily confirmed cases (cases)':'daily_cases',
                              'Daily confirmed deaths (deaths)':'daily_deaths'})
italy.insert(3, 'cases', np.cumsum(italy['daily_cases']))
italy.insert(3, 'deaths', np.cumsum(italy['daily_deaths']))
italy.plot.bar(y=['cases', 'daily_cases'], x='Date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11ebd5080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11ebed2e8>],
#       dtype=object)

# %%
italy.plot.bar(y=['deaths', 'daily_deaths'], x='Date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11e9579e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11f704080>],
#       dtype=object)

# %% [markdown]
# ## USA again

# %%
usa = world.loc[lambda df: df['Entity'] == 'United States']
usa = usa.rename(columns={'Daily confirmed cases (cases)':'daily_cases',
                          'Daily confirmed deaths (deaths)':'daily_deaths'})
usa.insert(3, 'cases', np.cumsum(usa['daily_cases']))
usa.insert(3, 'deaths', np.cumsum(usa['daily_deaths']))
usa.plot.bar(y=['cases', 'daily_cases'], x='Date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11f7b5b70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11fbbd940>],
#       dtype=object)

# %%
usa.plot.bar(y=['deaths', 'daily_deaths'], x='Date', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11f8a6cf8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1200875c0>],
#       dtype=object)
