# %%
install.packages('PoSI', repos='http://cloud.r-project.org')
# Out:
# The downloaded binary packages are in
# 	/var/folders/hl/77jshsz918s784wyd90rjw8m0000gr/T//Rtmp43yk9u/downloaded_packages

# %%
X = matrix(rnorm(5000), 250, 20)
library(PoSI)

# %%
?PoSI

# %%
data(Boston, package="MASS")
set.seed(1)
.Random.seed <- 1:626
UL.Boston <- PoSI(Boston[,-14])
summary(UL.Boston)
    ##     K.PoSI K.Bonferroni K.Scheffe
    ## 95%  3.593        4.904     4.729
    ## 99%  4.072        5.211     5.262
# Out:
# Number of contrasts/adjusted predictors to process: 53248
# Number of bundles: 13
#                          Done with bundle 1 / 13    model sz = 1
#                          Done with bundle 2 / 13    model sz = 2
#                          Done with bundle 3 / 13    model sz = 3
#                          Done with bundle 4 / 13    model sz = 4
#                          Done with bundle 5 / 13    model sz = 5
#                          Done with bundle 6 / 13    model sz = 6
#                          Done with bundle 7 / 13    model sz = 7
#                          Done with bundle 8 / 13    model sz = 8
#                          Done with bundle 9 / 13    model sz = 9
#                          Done with bundle 10 / 13    model sz = 10
#                          Done with bundle 11 / 13    model sz = 11
#                          Done with bundle 12 / 13    model sz = 12
#                          Done with bundle 13 / 13    model sz = 13
# p = 13 , d = 13   processed 53248 tests in 8191 models.  Times in seconds:
#    user  system elapsed
#   2.118   0.438   2.559
#     K.PoSI K.Bonferroni K.Scheffe
# 95% 3.593  4.904        4.729
# 99% 4.072  5.211        5.262

# %%
library(MASS)
data(Boston)

# %%
?Boston

# %%
library(glmnet)
Y = as.numeric(Boston[,14])
X = as.matrix(Boston[,-14])
random_order = sample(1:506, 506, replace=FALSE)
train = random_order[1:250]
test = random_order[251:506]
cvG = cv.glmnet(X[train,], Y[train])
plot(cvG)
# Out:
# plot without title

# %%
G = glmnet(X[train,], Y[train])
beta_train = coef(G, s=cvG$lambda.1se)[-1]
selected_train = which(beta_train != 0)
selected_train
# Out:
# [1]  1  4  5  6  8 11 12 13

# %%
selected_conf = confint(lm(Y ~ X[,selected_train], subset=test))
selected_conf
# Out:
#                            2.5 %         97.5 %
# (Intercept)                 18.632355371 46.80199415
# X[, selected_train]crim     -0.127172995  0.04333387
# X[, selected_train]chas      0.274071257  5.34307433
# X[, selected_train]nox     -25.256046835 -6.00138713
# X[, selected_train]rm        2.683336584  4.92847458
# X[, selected_train]dis      -1.400724546 -0.47748922
# X[, selected_train]ptratio  -1.406338243 -0.74066744
# X[, selected_train]black     0.003424072  0.01937714
# X[, selected_train]lstat    -0.645415429 -0.37155997

# %% [markdown]
# $\approxleq$

# %%
L_selected = selected_conf[,2] - selected_conf[,1]

# %%
cvG_all = cv.glmnet(X, Y)
G_all = glmnet(X, Y)
beta_all = coef(G, s=cvG_all$lambda.1se)[-1]
selected_all = which(beta_all != 0)
selected_all
# Out:
#  [1]  1  2  3  4  5  6  8 11 12 13

# %%
posi_conf = confint(lm(Y ~ X[,selected_all]), level=1 - 2 * pnorm(-3.593))

# %%
L_posi = posi_conf[,2] - posi_conf[,1]

# %%
data.frame(selected=L_selected, posi=L_posi)
# Out:
# Error in data.frame(selected = L_selected, posi = L_posi): arguments imply differing number of rows: 9, 11
# Traceback:
#
# 1. data.frame(selected = L_selected, posi = L_posi)
# 2. stop(gettextf("arguments imply differing number of rows: %s",
#  .     paste(unique(nrows), collapse = ", ")), domain = NA)
